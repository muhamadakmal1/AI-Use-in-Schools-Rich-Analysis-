# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/college-student-ai-use-in-school/AI On-Campus Research Survey (Responses).xlsx

# %% [markdown]
# **Import the Required Modules**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Set up is ready")
# Out:
# Set up is ready

# %% [markdown]
# **Load the Data**

# %%
df = pd.read_excel("/kaggle/input/college-student-ai-use-in-school/AI On-Campus Research Survey (Responses).xlsx")
df
# Out:
#                   Timestamp  \
# 0   2023-03-31 19:59:11.443
# 1   2023-03-31 19:59:44.970
# 2   2023-03-31 20:06:24.653
# 3   2023-03-31 20:10:54.939
# 4   2023-03-31 20:14:34.488
# ..                      ...
# 253 2023-10-24 14:02:43.753
# 254 2023-10-24 14:22:30.477
# 255 2023-10-25 10:08:07.129
# 256 2023-11-06 08:52:20.994
# 257 2024-01-25 14:51:10.920
#
#      On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?  \
# 0                                                    5
# 1                                                    4
# 2                                                    3
# 3                                                    4
# 4                                                    5
# ..                                                 ...
# 253                                                  5
# 254                                                  4
# 255                                                  4
# 256                                                  4
# 257                                                  4
#
#      On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?  \
# 0                                                    5
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 253                                                  2
# 254                                                  3
# 255                                                  3
# 256                                                  3
# 257                                                  2
#
#      On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?  \
# 0                                                    5
# 1                                                    4
# 2                                                    5
# 3                                                    5
# 4                                                    1
# ..                                                 ...
# 253                                                  3
# 254                                                  2
# 255                                                  3
# 256                                                  2
# 257                                                  2
#
#      On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?  \
# 0                                                    5
# 1                                                    4
# 2                                                    1
# 3                                                    2
# 4                                                    5
# ..                                                 ...
# 253                                                  3
# 254                                                  2
# 255                                                  2
# 256                                                  2
# 257                                                  2
#
#     Do you know what Chat-GPT is?            What college are you in?
# 0                             Yes  Science, Engineering, & Technology
# 1                             Yes  Science, Engineering, & Technology
# 2                              No                            Business
# 3                             Yes                            Business
# 4                             Yes        Humanities & Social Sciences
# ..                            ...                                 ...
# 253                           Yes  Science, Engineering, & Technology
# 254                           Yes                        Arts & Media
# 255                           Yes  Science, Engineering, & Technology
# 256                           Yes  Science, Engineering, & Technology
# 257                           Yes  Science, Engineering, & Technology
#
# [258 rows x 7 columns]

# %%
df.head()
# Out:
#                 Timestamp  \
# 0 2023-03-31 19:59:11.443
# 1 2023-03-31 19:59:44.970
# 2 2023-03-31 20:06:24.653
# 3 2023-03-31 20:10:54.939
# 4 2023-03-31 20:14:34.488
#
#    On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?  \
# 0                                                  5
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  5
#
#    On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?  \
# 0                                                  5
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  5
# 4                                                  1
#
#    On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?  \
# 0                                                  5
# 1                                                  4
# 2                                                  1
# 3                                                  2
# 4                                                  5
#
#   Do you know what Chat-GPT is?            What college are you in?
# 0                           Yes  Science, Engineering, & Technology
# 1                           Yes  Science, Engineering, & Technology
# 2                            No                            Business
# 3                           Yes                            Business
# 4                           Yes        Humanities & Social Sciences

# %%
df[df.columns]
# Out:
#                   Timestamp  \
# 0   2023-03-31 19:59:11.443
# 1   2023-03-31 19:59:44.970
# 2   2023-03-31 20:06:24.653
# 3   2023-03-31 20:10:54.939
# 4   2023-03-31 20:14:34.488
# ..                      ...
# 253 2023-10-24 14:02:43.753
# 254 2023-10-24 14:22:30.477
# 255 2023-10-25 10:08:07.129
# 256 2023-11-06 08:52:20.994
# 257 2024-01-25 14:51:10.920
#
#      On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?  \
# 0                                                    5
# 1                                                    4
# 2                                                    3
# 3                                                    4
# 4                                                    5
# ..                                                 ...
# 253                                                  5
# 254                                                  4
# 255                                                  4
# 256                                                  4
# 257                                                  4
#
#      On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?  \
# 0                                                    5
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 253                                                  2
# 254                                                  3
# 255                                                  3
# 256                                                  3
# 257                                                  2
#
#      On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?  \
# 0                                                    5
# 1                                                    4
# 2                                                    5
# 3                                                    5
# 4                                                    1
# ..                                                 ...
# 253                                                  3
# 254                                                  2
# 255                                                  3
# 256                                                  2
# 257                                                  2
#
#      On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?  \
# 0                                                    5
# 1                                                    4
# 2                                                    1
# 3                                                    2
# 4                                                    5
# ..                                                 ...
# 253                                                  3
# 254                                                  2
# 255                                                  2
# 256                                                  2
# 257                                                  2
#
#     Do you know what Chat-GPT is?            What college are you in?
# 0                             Yes  Science, Engineering, & Technology
# 1                             Yes  Science, Engineering, & Technology
# 2                              No                            Business
# 3                             Yes                            Business
# 4                             Yes        Humanities & Social Sciences
# ..                            ...                                 ...
# 253                           Yes  Science, Engineering, & Technology
# 254                           Yes                        Arts & Media
# 255                           Yes  Science, Engineering, & Technology
# 256                           Yes  Science, Engineering, & Technology
# 257                           Yes  Science, Engineering, & Technology
#
# [258 rows x 7 columns]

# %%
df.size
# Out:
# 1806

# %%
df.shape
# Out:
# (258, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                        --------------  -----
#  0   Timestamp                                                                                                     258 non-null    datetime64[ns]
#  1   On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?  258 non-null    int64
#  2   On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?                   258 non-null    int64
#  3   On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?           258 non-null    int64
#  4   On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?               258 non-null    int64
#  5   Do you know what Chat-GPT is?                                                                                 258 non-null    object
#  6   What college are you in?                                                                                      258 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 14.2+ KB

# %%
df.describe()
# Out:
#                            Timestamp  \
# count                            258
# mean   2023-04-21 18:28:58.153763584
# min       2023-03-31 19:59:11.443000
# 25%    2023-04-06 08:26:21.530749952
# 50%    2023-04-11 12:48:24.440999936
# 75%    2023-04-19 14:33:23.658249984
# max       2024-01-25 14:51:10.920000
# std                              NaN
#
#        On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?  \
# count                                         258.000000
# mean                                            3.294574
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
# std                                             0.973606
#
#        On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?  \
# count                                         258.000000
# mean                                            2.244186
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
# std                                             1.020445
#
#        On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?  \
# count                                         258.000000
# mean                                            2.104651
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
# std                                             1.216256
#
#        On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?
# count                                         258.000000
# mean                                            1.794574
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             5.000000
# std                                             1.177137

# %%
df['On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?'].value_counts()
# Out:
# On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?
# 3    97
# 4    84
# 2    42
# 5    26
# 1     9
# Name: count, dtype: int64

# %%
df['On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?'].value_counts()
# Out:
# On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?
# 2    90
# 1    70
# 3    68
# 4    25
# 5     5
# Name: count, dtype: int64

# %%
df['On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?'].value_counts()
# Out:
# On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?
# 1    111
# 2     64
# 3     40
# 4     31
# 5     12
# Name: count, dtype: int64

# %%
df['On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?'].value_counts()
# Out:
# On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?
# 1    150
# 2     55
# 3     25
# 5     16
# 4     12
# Name: count, dtype: int64

# %%
df[['Do you know what Chat-GPT is?', 'What college are you in?']].value_counts()
# Out:
# Do you know what Chat-GPT is?  What college are you in?
# Yes                            Science, Engineering, & Technology    94
#                                Business                              55
#                                Humanities & Social Sciences          32
#                                Arts & Media                          11
# No                             Business                              10
# Yes                            Nursing & Health Care                 10
# No                             Science, Engineering, & Technology     9
# Yes                            Education                              9
# No                             Humanities & Social Sciences           7
# Yes                            Theology                               7
# No                             Nursing & Health Care                  6
#                                Education                              4
#                                Arts & Media                           1
# Yes                            Business and education                 1
#                                Can you email Robert.loy@gcu.edu       1
#                                CreamAToligy                           1
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Data Analysis**

# %%
data1 = df['On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?'].value_counts().sort_index()
data2 = df['On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?'].value_counts().sort_index()
data3 = df['On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?'].value_counts().sort_index()
data4 = df['On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?'].value_counts().sort_index()

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 9))

# Plot data on each subplot
data1.plot(kind='bar', ax=axes[0, 0])
data2.plot(kind='bar', ax=axes[0, 1])
data3.plot(kind='bar', ax=axes[1, 0])
data4.plot(kind='bar', ax=axes[1, 1])

# Set titles and labels
axes[0, 0].set_title('Usage of AI for Personal Use')
axes[0, 1].set_title('Knowledge and Understanding of AI')
axes[1, 0].set_title('Usage of AI for School-related Tasks')
axes[1, 1].set_title('Interest in Pursuing a Career in AI')
for ax in axes.flat:
    ax.set_xlabel('Rating')
    ax.set_ylabel('Frequency')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0)

# Show the plot
plt.show()

# %%
average_knowledge = df['On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?'].mean()
print("Average Knowledge of AI:", average_knowledge)

# Frequency of AI usage for personal use
average_personal_usage = df['On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?'].mean()
print("Average Personal Usage of AI:", average_personal_usage)

# Most common level of interest in pursuing a career in AI
common_interest = df['On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?'].mode()[0]
print("Most Common Interest in AI Career:", common_interest)
# Out:
# Average Knowledge of AI: 3.294573643410853
# Average Personal Usage of AI: 2.244186046511628
# Most Common Interest in AI Career: 1

# %%
num_cols = df.select_dtypes(include='number').columns
cat_cols = df.select_dtypes(include='object').columns

# %%
corr = df[num_cols].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
df[cat_cols].nunique()
# Out:
# Do you know what Chat-GPT is?     2
# What college are you in?         10
# dtype: int64

# %%
df.hist(figsize = (20,15))
# Out:
# array([[<Axes: title={'center': 'Timestamp'}>,
#         <Axes: title={'center': 'On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?'}>],
#        [<Axes: title={'center': 'On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?'}>,
#         <Axes: title={'center': 'On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?'}>],
#        [<Axes: title={'center': 'On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?'}>,
#         <Axes: >]], dtype=object)

# %%
df[cat_cols].nunique()
# Out:
# Do you know what Chat-GPT is?     2
# What college are you in?         10
# dtype: int64

# %%
plt.figure(figsize=(12, 8))
df['Do you know what Chat-GPT is?'].value_counts().plot(kind='pie')
plt.title("Do you know what Chat-GPT is?")
plt.show()

# %%
palette = sns.color_palette('pastel')
plt.figure(figsize=(12, 8))
df['On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?'].value_counts().plot(kind='bar', color=palette)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '1'),
#   Text(1, 0, '2'),
#   Text(2, 0, '3'),
#   Text(3, 0, '4'),
#   Text(4, 0, '5')])

# %%
plt.figure(figsize=(12, 8))
df['On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?']\
                                                                                .value_counts().plot(kind='bar', color=palette)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '3'),
#   Text(1, 0, '4'),
#   Text(2, 0, '2'),
#   Text(3, 0, '5'),
#   Text(4, 0, '1')])

# %%
df.columns
# Out:
# Index(['Timestamp',
#        'On a scale from 1 to 5, how would you rate your knowledge and understanding of Artificial Intelligence (AI)?',
#        'On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?',
#        'On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?',
#        'On a scale from 1 to 5, how interested are you in pursuing a career in Artificial Intelligence?',
#        'Do you know what Chat-GPT is?', 'What college are you in?'],
#       dtype='object')

# %%
df = df.drop((df[df['What college are you in?'] == 'Can you email Robert.loy@gcu.edu']).index)

# %%
df['What college are you in?'].unique()
# Out:
# array(['Science, Engineering, & Technology', 'Business',
#        'Humanities & Social Sciences', 'Nursing & Health Care',
#        'Arts & Media', 'Theology', 'Education', 'Business and education',
#        'CreamAToligy'], dtype=object)

# %%
# Define the x-labels and legend labels
x_labels = [
    'Science, Eng. & Tech.', 'Business', 'Humanities & Soc. Sci.', 'Nursing & Health Care',
    'Arts & Media', 'Theology', 'Education', 'Business and Education', 'CreamAToligy'
]
legend_labels = [
    'Personal Use (AI)', 'School-Related Tasks (AI)'
]

# Plotting
plt.figure(figsize=(12, 8))
plot_data = df.groupby('What college are you in?')[['On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for personal use?', 
                                                    'On a scale from 1 to 5, how often do you use Artificial Intelligence (AI) for school-related tasks?']].mean()\
                                                    .plot(kind='bar', color=palette, figsize=(20, 10))

plot_data.set_xticklabels(x_labels)
plot_data.legend(legend_labels)

for bar in plot_data.patches:
    x = bar.get_x() + bar.get_width() / 2
    y = bar.get_height()
    label = f'{y:.2f}'
    plot_data.annotate(label, (x, y), textcoords="offset points", xytext=(0, 5), ha='center')

    
plot_data.set_ylabel('Average Rating')
plt.title('Usage of Artificial Intelligence (AI) by Department')
plt.xticks(rotation = 45)
plt.show()
